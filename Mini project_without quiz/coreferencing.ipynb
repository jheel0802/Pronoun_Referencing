# %%
from stanfordcorenlp import StanfordCoreNLP
import json

# %%
# Set the path to the directory containing the Stanford CoreNLP library
path_to_corenlp = 'C:/Users/Admin/Desktop/sem 6/mp/stanford-corenlp-4.5.4'

# Start the Stanford CoreNLP server
nlp = StanfordCoreNLP(path_to_corenlp)

# %%
# example text to analyze
text = "Hetal and Priya were going to Kashmir but they forgot to bring warm clothing with them.There they saw beautiful birds"

# %%
# Annotate the text with coreference resolution
annotated_text = nlp.annotate(text, properties={
    'annotators': 'coref',
    'outputFormat': 'json',
    'timeout': 15000,
})

# %%
print(annotated_text)
# Out:
# {
#   "sentences": [
#     {
#       "index": 0,
#       "basicDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 5,
#           "dependentGloss": "going"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 1,
#           "dependentGloss": "Hetal"
#         },
#         {
#           "dep": "cc",
#           "governor": 3,
#           "governorGloss": "Priya",
#           "dependent": 2,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "conj",
#           "governor": 1,
#           "governorGloss": "Hetal",
#           "dependent": 3,
#           "dependentGloss": "Priya"
#         },
#         {
#           "dep": "aux",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 4,
#           "dependentGloss": "were"
#         },
#         {
#           "dep": "case",
#           "governor": 7,
#           "governorGloss": "Kashmir",
#           "dependent": 6,
#           "dependentGloss": "to"
#         },
#         {
#           "dep": "obl",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 7,
#           "dependentGloss": "Kashmir"
#         },
#         {
#           "dep": "cc",
#           "governor": 10,
#           "governorGloss": "forgot",
#           "dependent": 8,
#           "dependentGloss": "but"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 10,
#           "governorGloss": "forgot",
#           "dependent": 9,
#           "dependentGloss": "they"
#         },
#         {
#           "dep": "conj",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 10,
#           "dependentGloss": "forgot"
#         },
#         {
#           "dep": "mark",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 11,
#           "dependentGloss": "to"
#         },
#         {
#           "dep": "xcomp",
#           "governor": 10,
#           "governorGloss": "forgot",
#           "dependent": 12,
#           "dependentGloss": "bring"
#         },
#         {
#           "dep": "amod",
#           "governor": 14,
#           "governorGloss": "clothing",
#           "dependent": 13,
#           "dependentGloss": "warm"
#         },
#         {
#           "dep": "obj",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 14,
#           "dependentGloss": "clothing"
#         },
#         {
#           "dep": "case",
#           "governor": 16,
#           "governorGloss": "them.There",
#           "dependent": 15,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "obl",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 16,
#           "dependentGloss": "them.There"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 18,
#           "governorGloss": "saw",
#           "dependent": 17,
#           "dependentGloss": "they"
#         },
#         {
#           "dep": "parataxis",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 18,
#           "dependentGloss": "saw"
#         },
#         {
#           "dep": "amod",
#           "governor": 20,
#           "governorGloss": "birds",
#           "dependent": 19,
#           "dependentGloss": "beautiful"
#         },
#         {
#           "dep": "obj",
#           "governor": 18,
#           "governorGloss": "saw",
#           "dependent": 20,
#           "dependentGloss": "birds"
#         }
#       ],
#       "enhancedDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 5,
#           "dependentGloss": "going"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 1,
#           "dependentGloss": "Hetal"
#         },
#         {
#           "dep": "cc",
#           "governor": 3,
#           "governorGloss": "Priya",
#           "dependent": 2,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "conj:and",
#           "governor": 1,
#           "governorGloss": "Hetal",
#           "dependent": 3,
#           "dependentGloss": "Priya"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 3,
#           "dependentGloss": "Priya"
#         },
#         {
#           "dep": "aux",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 4,
#           "dependentGloss": "were"
#         },
#         {
#           "dep": "case",
#           "governor": 7,
#           "governorGloss": "Kashmir",
#           "dependent": 6,
#           "dependentGloss": "to"
#         },
#         {
#           "dep": "obl:to",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 7,
#           "dependentGloss": "Kashmir"
#         },
#         {
#           "dep": "cc",
#           "governor": 10,
#           "governorGloss": "forgot",
#           "dependent": 8,
#           "dependentGloss": "but"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 10,
#           "governorGloss": "forgot",
#           "dependent": 9,
#           "dependentGloss": "they"
#         },
#         {
#           "dep": "nsubj:xsubj",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 9,
#           "dependentGloss": "they"
#         },
#         {
#           "dep": "conj:but",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 10,
#           "dependentGloss": "forgot"
#         },
#         {
#           "dep": "mark",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 11,
#           "dependentGloss": "to"
#         },
#         {
#           "dep": "xcomp",
#           "governor": 10,
#           "governorGloss": "forgot",
#           "dependent": 12,
#           "dependentGloss": "bring"
#         },
#         {
#           "dep": "amod",
#           "governor": 14,
#           "governorGloss": "clothing",
#           "dependent": 13,
#           "dependentGloss": "warm"
#         },
#         {
#           "dep": "obj",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 14,
#           "dependentGloss": "clothing"
#         },
#         {
#           "dep": "case",
#           "governor": 16,
#           "governorGloss": "them.There",
#           "dependent": 15,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "obl:with",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 16,
#           "dependentGloss": "them.There"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 18,
#           "governorGloss": "saw",
#           "dependent": 17,
#           "dependentGloss": "they"
#         },
#         {
#           "dep": "parataxis",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 18,
#           "dependentGloss": "saw"
#         },
#         {
#           "dep": "amod",
#           "governor": 20,
#           "governorGloss": "birds",
#           "dependent": 19,
#           "dependentGloss": "beautiful"
#         },
#         {
#           "dep": "obj",
#           "governor": 18,
#           "governorGloss": "saw",
#           "dependent": 20,
#           "dependentGloss": "birds"
#         }
#       ],
#       "enhancedPlusPlusDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 5,
#           "dependentGloss": "going"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 1,
#           "dependentGloss": "Hetal"
#         },
#         {
#           "dep": "cc",
#           "governor": 3,
#           "governorGloss": "Priya",
#           "dependent": 2,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "conj:and",
#           "governor": 1,
#           "governorGloss": "Hetal",
#           "dependent": 3,
#           "dependentGloss": "Priya"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 3,
#           "dependentGloss": "Priya"
#         },
#         {
#           "dep": "aux",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 4,
#           "dependentGloss": "were"
#         },
#         {
#           "dep": "case",
#           "governor": 7,
#           "governorGloss": "Kashmir",
#           "dependent": 6,
#           "dependentGloss": "to"
#         },
#         {
#           "dep": "obl:to",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 7,
#           "dependentGloss": "Kashmir"
#         },
#         {
#           "dep": "cc",
#           "governor": 10,
#           "governorGloss": "forgot",
#           "dependent": 8,
#           "dependentGloss": "but"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 10,
#           "governorGloss": "forgot",
#           "dependent": 9,
#           "dependentGloss": "they"
#         },
#         {
#           "dep": "nsubj:xsubj",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 9,
#           "dependentGloss": "they"
#         },
#         {
#           "dep": "conj:but",
#           "governor": 5,
#           "governorGloss": "going",
#           "dependent": 10,
#           "dependentGloss": "forgot"
#         },
#         {
#           "dep": "mark",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 11,
#           "dependentGloss": "to"
#         },
#         {
#           "dep": "xcomp",
#           "governor": 10,
#           "governorGloss": "forgot",
#           "dependent": 12,
#           "dependentGloss": "bring"
#         },
#         {
#           "dep": "amod",
#           "governor": 14,
#           "governorGloss": "clothing",
#           "dependent": 13,
#           "dependentGloss": "warm"
#         },
#         {
#           "dep": "obj",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 14,
#           "dependentGloss": "clothing"
#         },
#         {
#           "dep": "case",
#           "governor": 16,
#           "governorGloss": "them.There",
#           "dependent": 15,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "obl:with",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 16,
#           "dependentGloss": "them.There"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 18,
#           "governorGloss": "saw",
#           "dependent": 17,
#           "dependentGloss": "they"
#         },
#         {
#           "dep": "parataxis",
#           "governor": 12,
#           "governorGloss": "bring",
#           "dependent": 18,
#           "dependentGloss": "saw"
#         },
#         {
#           "dep": "amod",
#           "governor": 20,
#           "governorGloss": "birds",
#           "dependent": 19,
#           "dependentGloss": "beautiful"
#         },
#         {
#           "dep": "obj",
#           "governor": 18,
#           "governorGloss": "saw",
#           "dependent": 20,
#           "dependentGloss": "birds"
#         }
#       ],
#       "entitymentions": [
#         {
#           "docTokenBegin": 0,
#           "docTokenEnd": 1,
#           "tokenBegin": 0,
#           "tokenEnd": 1,
#           "text": "Hetal",
#           "characterOffsetBegin": 0,
#           "characterOffsetEnd": 5,
#           "ner": "PERSON",
#           "nerConfidences": {
#             "PERSON": 0.56218470851857
#           }
#         },
#         {
#           "docTokenBegin": 2,
#           "docTokenEnd": 3,
#           "tokenBegin": 2,
#           "tokenEnd": 3,
#           "text": "Priya",
#           "characterOffsetBegin": 10,
#           "characterOffsetEnd": 15,
#           "ner": "PERSON",
#           "nerConfidences": {
#             "PERSON": 0.55460869827188
#           }
#         },
#         {
#           "docTokenBegin": 6,
#           "docTokenEnd": 7,
#           "tokenBegin": 6,
#           "tokenEnd": 7,
#           "text": "Kashmir",
#           "characterOffsetBegin": 30,
#           "characterOffsetEnd": 37,
#           "ner": "LOCATION",
#           "nerConfidences": {
#             "LOCATION": 0.99925719256782
#           }
#         }
#       ],
#       "tokens": [
#         {
#           "index": 1,
#           "word": "Hetal",
#           "originalText": "Hetal",
#           "lemma": "Hetal",
#           "characterOffsetBegin": 0,
#           "characterOffsetEnd": 5,
#           "pos": "NNP",
#           "ner": "PERSON",
#           "speaker": "PER0",
#           "before": "",
#           "after": " "
#         },
#         {
#           "index": 2,
#           "word": "and",
#           "originalText": "and",
#           "lemma": "and",
#           "characterOffsetBegin": 6,
#           "characterOffsetEnd": 9,
#           "pos": "CC",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 3,
#           "word": "Priya",
#           "originalText": "Priya",
#           "lemma": "Priya",
#           "characterOffsetBegin": 10,
#           "characterOffsetEnd": 15,
#           "pos": "NNP",
#           "ner": "PERSON",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 4,
#           "word": "were",
#           "originalText": "were",
#           "lemma": "be",
#           "characterOffsetBegin": 16,
#           "characterOffsetEnd": 20,
#           "pos": "VBD",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 5,
#           "word": "going",
#           "originalText": "going",
#           "lemma": "go",
#           "characterOffsetBegin": 21,
#           "characterOffsetEnd": 26,
#           "pos": "VBG",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 6,
#           "word": "to",
#           "originalText": "to",
#           "lemma": "to",
#           "characterOffsetBegin": 27,
#           "characterOffsetEnd": 29,
#           "pos": "IN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 7,
#           "word": "Kashmir",
#           "originalText": "Kashmir",
#           "lemma": "Kashmir",
#           "characterOffsetBegin": 30,
#           "characterOffsetEnd": 37,
#           "pos": "NNP",
#           "ner": "LOCATION",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 8,
#           "word": "but",
#           "originalText": "but",
#           "lemma": "but",
#           "characterOffsetBegin": 38,
#           "characterOffsetEnd": 41,
#           "pos": "CC",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 9,
#           "word": "they",
#           "originalText": "they",
#           "lemma": "they",
#           "characterOffsetBegin": 42,
#           "characterOffsetEnd": 46,
#           "pos": "PRP",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 10,
#           "word": "forgot",
#           "originalText": "forgot",
#           "lemma": "forget",
#           "characterOffsetBegin": 47,
#           "characterOffsetEnd": 53,
#           "pos": "VBD",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 11,
#           "word": "to",
#           "originalText": "to",
#           "lemma": "to",
#           "characterOffsetBegin": 54,
#           "characterOffsetEnd": 56,
#           "pos": "TO",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 12,
#           "word": "bring",
#           "originalText": "bring",
#           "lemma": "bring",
#           "characterOffsetBegin": 57,
#           "characterOffsetEnd": 62,
#           "pos": "VB",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 13,
#           "word": "warm",
#           "originalText": "warm",
#           "lemma": "warm",
#           "characterOffsetBegin": 63,
#           "characterOffsetEnd": 67,
#           "pos": "JJ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 14,
#           "word": "clothing",
#           "originalText": "clothing",
#           "lemma": "clothing",
#           "characterOffsetBegin": 68,
#           "characterOffsetEnd": 76,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 15,
#           "word": "with",
#           "originalText": "with",
#           "lemma": "with",
#           "characterOffsetBegin": 77,
#           "characterOffsetEnd": 81,
#           "pos": "IN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 16,
#           "word": "them.There",
#           "originalText": "them.There",
#           "lemma": "them.there",
#           "characterOffsetBegin": 82,
#           "characterOffsetEnd": 92,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 17,
#           "word": "they",
#           "originalText": "they",
#           "lemma": "they",
#           "characterOffsetBegin": 93,
#           "characterOffsetEnd": 97,
#           "pos": "PRP",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 18,
#           "word": "saw",
#           "originalText": "saw",
#           "lemma": "see",
#           "characterOffsetBegin": 98,
#           "characterOffsetEnd": 101,
#           "pos": "VBD",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 19,
#           "word": "beautiful",
#           "originalText": "beautiful",
#           "lemma": "beautiful",
#           "characterOffsetBegin": 102,
#           "characterOffsetEnd": 111,
#           "pos": "JJ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 20,
#           "word": "birds",
#           "originalText": "birds",
#           "lemma": "bird",
#           "characterOffsetBegin": 112,
#           "characterOffsetEnd": 117,
#           "pos": "NNS",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": ""
#         }
#       ]
#     }
#   ],
#   "corefs": {
#     "6": [
#       {
#         "id": 2,
#         "text": "Hetal and Priya",
#         "type": "LIST",
#         "number": "PLURAL",
#         "gender": "UNKNOWN",
#         "animacy": "ANIMATE",
#         "startIndex": 1,
#         "endIndex": 4,
#         "headIndex": 1,
#         "sentNum": 1,
#         "position": [
#           1,
#           3
#         ],
#         "isRepresentativeMention": true
#       },
#       {
#         "id": 3,
#         "text": "they",
#         "type": "PRONOMINAL",
#         "number": "PLURAL",
#         "gender": "UNKNOWN",
#         "animacy": "ANIMATE",
#         "startIndex": 9,
#         "endIndex": 10,
#         "headIndex": 9,
#         "sentNum": 1,
#         "position": [
#           1,
#           4
#         ],
#         "isRepresentativeMention": false
#       },
#       {
#         "id": 6,
#         "text": "they",
#         "type": "PRONOMINAL",
#         "number": "PLURAL",
#         "gender": "UNKNOWN",
#         "animacy": "ANIMATE",
#         "startIndex": 17,
#         "endIndex": 18,
#         "headIndex": 17,
#         "sentNum": 1,
#         "position": [
#           1,
#           7
#         ],
#         "isRepresentativeMention": false
#       }
#     ]
#   }
# }

# %%
coreferences = []
json_load = (json.loads(annotated_text))
# print(json_load['corefs'].values())
for cluster in json_load['corefs'].values():
    word_group = []
    for connections in cluster:
        word_group.append(connections['text'])
    coreferences.append(word_group)
print("text:",text)
print(coreferences)
# Out:
# text: Hetal and Priya were going to Kashmir but they forgot to bring warm clothing with them.There they saw beautiful birds
# [['Hetal and Priya', 'they', 'they']]

# %%
# coreferences = []
# for coref in annotated_text.corefs:
#     for mention in coref['mentions']:
#         if mention['isRepresentativeMention']:
#             representative_text = mention['text']
#             representative_cluster_id = coref['corefClusterID']
#         else:
#             coreferences.append({'text': mention['text'], 'cluster_id': coref['corefClusterID'], 'arepresentative_text': representative_text, 'representative_cluster_id': representative_cluster_id})

# %%
# print the pronoun references
# for coref in coreferences:
#     cluster_id = coref['cluster_id']
#     for sentence in annotated_text['sentences']:
#         for word in sentence['tokens']:
#             if 'corefClusterID' in word and word['corefClusterID'] == cluster_id:
#                 print(f"{coref['text']} refers to {word['originalText']} in sentence '{sentence['text']}'")
#                 break

# close the CoreNLP client
# nlp.close()

# %%
# define the sentence
sentence = "Ram and Rahul encountered beautiful forest, breathtaking waterfall and mountainside view where they discovered gold and silver."
x = []
# process the sentence
doc = nlp(sentence)

# start the reverse traversal from the end of the sentence
i = len(doc.sentences[0].words) - 1
print(i)
while i >= 0:
    # if a word has deprel "conj", start a second pointer j to find the subject deprel
    if doc.sentences[0].words[i].deprel == "conj":
        # print("hit:",i)
        j = i - 1
        while j >= 0:
            # if a subject deprel is found, print the words from j to i
            if doc.sentences[0].words[j].deprel.startswith("obl") or doc.sentences[0].words[j].deprel.startswith("nsubj") or doc.sentences[0].words[j].deprel.startswith("obj"):
                words = [word.text for word in doc.sentences[0].words[j:i+1]]
                x.append(" ".join(words))
                break
            j -= 1
        # start the next traversal from the position before the subject deprel word
        i = j - 1
    else:
        # print("else hit:",i)
        i -= 1
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       3 x = []
#       4 # process the sentence
# ----> 5 doc = nlp(sentence)
#       7 # start the reverse traversal from the end of the sentence
#       8 i = len(doc.sentences[0].words) - 1
#
# TypeError: 'StanfordCoreNLP' object is not callable

# %%
import stanza
# download the English language model
stanza.download('en')
# initialize the pipeline

# %%
nlp_ = stanza.Pipeline('en')

# %%
# define the sentence
sentence = "Ram and Rahul were told to come back before sunset but they chose to ignore the warnings."
x = []
# process the sentence
doc = nlp_(sentence)

# start the reverse traversal from the end of the sentence
i = len(doc.sentences[0].words) - 1
print(i)
while i >= 0:
    # if a word has deprel "conj", start a second pointer j to find the subject deprel
    if doc.sentences[0].words[i].deprel == "conj":
        # print("hit:",i)
        j = i - 1
        while j >= 0:
            # if a subject deprel is found, print the words from j to i
            if doc.sentences[0].words[j].deprel.startswith("obl") or doc.sentences[0].words[j].deprel.startswith("nsubj") or doc.sentences[0].words[j].deprel.startswith("obj"):
                words = [word.text for word in doc.sentences[0].words[j:i+1]]
                x.append(" ".join(words))
                break
            j -= 1
        # start the next traversal from the position before the subject deprel word
        i = j - 1
    else:
        # print("else hit:",i)
        i -= 1
print(x)
